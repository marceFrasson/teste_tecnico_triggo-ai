# %% [markdown]
# # **inicialização**

# %% [markdown]
# ## importar bibliotecas

# %%
# !pip install haversine

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import sqlite3
from datetime import date
from datetime import datetime
from statsmodels.tsa.seasonal import seasonal_decompose
from haversine import haversine, Unit

# %% [markdown]
# ## montar Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### checar arquivos da pasta

# %%
# !ls drive/"My Drive/Colab Notebooks"
# Out:
# olist_customers_dataset.csv	  olist_orders_dataset.csv
# olist_geolocation_dataset.csv	  olist_products_dataset.csv
# olist_order_items_dataset.csv	  olist_sellers_dataset.csv
# olist_order_payments_dataset.csv  product_category_name_translation.csv
# olist_order_reviews_dataset.csv   teste_tecnico.ipynb

# %% [markdown]
# ## importar todos os datasets

# %%
import os
import glob

# %%
#  caminho da pasta que contem este arquivo
folder_path = r'drive/My Drive/Colab Notebooks'

#  cria uma lista com o nome de cada arquivo csv
files = glob.glob(os.path.join(folder_path, "*.csv"))

#  dicionário que armazenará os arquivos csv e seus respectivos nomes
files_dict = {}


for file_path in files:
  #  lista com o nome de cada arquivo
  filename = os.path.basename(file_path).replace('olist_', '') \
  .replace('_dataset', '').replace('.csv', '')
  #  escreve no dicionário cada arquivo associado ao seu dataset
  files_dict[filename] = pd.read_csv(file_path)


# atribuir datasets às variáveis correpondetes
df_customers, df_geolocation, df_order_items, df_order_payments, \
df_orders, df_order_reviews, df_products, df_sellers,\
df_product_category_name_translation = files_dict.values()

# %% [markdown]
# ### checar nomes dos arquivos importados

# %%
for filename in files_dict:
  print(filename)
# Out:
# customers
# geolocation
# order_items
# order_payments
# orders
# order_reviews
# products
# sellers
# product_category_name_translation

# %% [markdown]
# # **datasets**

# %% [markdown]
# ### ***customers***

# %% [markdown]
# #### df_customers

# %%
df_customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %% [markdown]
# #### df_customers info and describe

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
df_customers.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# ### ***geolocation***

# %% [markdown]
# #### df_geolocation

# %%
df_geolocation
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %% [markdown]
# #### geolocation info and describe

# %%
df_geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
df_geolocation.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %% [markdown]
# ### ***order_items***

# %% [markdown]
# #### df_order_items

# %%
df_order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %% [markdown]
# #### order_items info and describe

# %%
df_order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
df_order_items.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# ### ***order_payments***

# %% [markdown]
# #### df_order_payments

# %%
df_order_payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# #### oder_payments info and describe

# %%
df_order_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
df_order_payments.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# ### ***order_reviews*** *** ~ ( não tratar nulos ) ~ ***

# %% [markdown]
# #### df_order_reviews

# %%
df_order_reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# #### order_reviews info and describe

# %%
df_order_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
df_order_reviews.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# #### null

# %%
df_order_reviews.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
null_reviews = df_order_reviews[df_order_reviews.isnull().any(axis=1)]
null_reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# ### ***orders*** *** ~ ( tratar nulos ) ~ ***

# %% [markdown]
# #### df_orders

# %%
df_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %% [markdown]
# #### df_orders info and describe

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
df_orders.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-08-02 12:06:07  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# #### null

# %%
df_orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
null_orders = df_orders[df_orders.isnull().any(axis=1)]
null_orders
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
counts_df = df_orders['order_status'].value_counts()
counts_df
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
counts = null_orders['order_status'].value_counts()
counts
# Out:
# order_status
# shipped        1107
# canceled        619
# unavailable     609
# invoiced        314
# processing      301
# delivered        23
# created           5
# approved          2
# Name: count, dtype: int64

# %% [markdown]
# ##### null 'order_approved_at'

# %%
null_orders_at = df_orders[df_orders['order_approved_at'].isnull()]
null_orders_at
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
set(null_orders_at['order_status'])
# Out:
# {'canceled', 'created', 'delivered'}

# %%
at_counts = null_orders_at['order_status'].value_counts()
at_counts
# Out:
# order_status
# canceled     141
# delivered     14
# created        5
# Name: count, dtype: int64

# %%
filter_created = null_orders_at[null_orders_at['order_status'] == 'created']
filter_created
# Out:
#                                order_id                       customer_id  \
# 7434   b5359909123fa03c50bdb0cfed07f098  438449d4af8980d107bf04571413a8e7
# 9238   dba5062fbda3af4fb6c33b1e040ca38f  964a6df3d9bdf60fe3e7b8bb69ed893a
# 21441  7a4df5d8cff4090e541401a20a22bb80  725e9c75605414b21fd8c8d5a1c2f1d6
# 55086  35de4050331c6c644cddc86f4f2d0d64  4ee64f4bfc542546f422da0aeb462853
# 58958  90ab3e7d52544ec7bc3363c82689965f  7d61b9f4f216052ba664f22e9c504ef1
#
#       order_status order_purchase_timestamp order_approved_at  \
# 7434       created      2017-12-05 01:07:52               NaN
# 9238       created      2018-02-09 17:21:04               NaN
# 21441      created      2017-11-25 11:10:33               NaN
# 55086      created      2017-12-05 01:07:58               NaN
# 58958      created      2017-11-06 13:12:34               NaN
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 7434                           NaN                           NaN
# ...

# %%
filter_delivered = null_orders_at[null_orders_at['order_status'] == 'delivered']
filter_delivered
# Out:
#                                order_id                       customer_id  \
# 5323   e04abd8149ef81b95221e88f6ed9ab6a  2127dc6603ac33544953ef05ec155771
# 16567  8a9adc69528e1001fc68dd0aaebbb54a  4c1ccc74e00993733742a3c786dc3c1f
# 19031  7013bcfc1c97fe719a7b5e05e61c12db  2941af76d38100e0f8740a374f1a5dc3
# 22663  5cf925b116421afa85ee25e99b4c34fb  29c35fc91fc13fb5073c8f30505d860d
# 23156  12a95a3c06dbaec84bcfb0e2da5d228a  1e101e0daffaddce8159d25a8e53f2b2
# 26800  c1d4211b3dae76144deccd6c74144a88  684cb238dc5b5d6366244e0e0776b450
# 38290  d69e5d356402adc8cf17e08b5033acfb  68d081753ad4fe22fc4d410a9eb1ca01
# 39334  d77031d6a3c8a52f019764e68f211c69  0bf35cac6cc7327065da879e2d90fae8
# 48401  7002a78c79c519ac54022d4f8a65e6e8  d5de688c321096d15508faae67a27051
# 61743  2eecb0d85f281280f79fa00f9cec1a95  a3d3c38e58b9d2dfb9207cab690b6310
# 63052  51eb2eebd5d76a24625b31c33dd41449  07a2a7e0f63fd8cb757ed77d4245623c
# 67697  88083e8f64d95b932164187484d90212  f67cd1a215aae2a1074638bbd35a223a
# ...

# %% [markdown]
# ##### null 'order_status'

# %%
filtered_approved = null_orders[null_orders['order_status'] == 'approved']
filtered_approved
# Out:
#                                order_id                       customer_id  \
# 44897  a2e4c44360b4a57bdff22f3a4630c173  8886130db0ea6e9e70ba0b03d7c0d286
# 88457  132f1e724165a07f6362532bfb97486e  b2191912d8ad6eac2e4dc3b6e1459515
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 44897     approved      2017-02-06 20:18:17  2017-02-06 20:30:19
# 88457     approved      2017-04-25 01:25:34  2017-04-30 20:32:41
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 44897                          NaN                           NaN
# 88457                          NaN                           NaN
#
#       order_estimated_delivery_date
# 44897           2017-03-01 00:00:00
# 88457           2017-05-22 00:00:00

# %%
filtered_approved = null_orders[null_orders['order_status'] == 'created']
filtered_approved
# Out:
#                                order_id                       customer_id  \
# 7434   b5359909123fa03c50bdb0cfed07f098  438449d4af8980d107bf04571413a8e7
# 9238   dba5062fbda3af4fb6c33b1e040ca38f  964a6df3d9bdf60fe3e7b8bb69ed893a
# 21441  7a4df5d8cff4090e541401a20a22bb80  725e9c75605414b21fd8c8d5a1c2f1d6
# 55086  35de4050331c6c644cddc86f4f2d0d64  4ee64f4bfc542546f422da0aeb462853
# 58958  90ab3e7d52544ec7bc3363c82689965f  7d61b9f4f216052ba664f22e9c504ef1
#
#       order_status order_purchase_timestamp order_approved_at  \
# 7434       created      2017-12-05 01:07:52               NaN
# 9238       created      2018-02-09 17:21:04               NaN
# 21441      created      2017-11-25 11:10:33               NaN
# 55086      created      2017-12-05 01:07:58               NaN
# 58958      created      2017-11-06 13:12:34               NaN
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 7434                           NaN                           NaN
# ...

# %%
filtered_approved = null_orders[null_orders['order_status'] == 'delivered']
filtered_approved
# Out:
#                                order_id                       customer_id  \
# 3002   2d1e2d5bf4dc7227b3bfebb81328c15f  ec05a6d8558c6455f0cbbd8a420ad34f
# 5323   e04abd8149ef81b95221e88f6ed9ab6a  2127dc6603ac33544953ef05ec155771
# 16567  8a9adc69528e1001fc68dd0aaebbb54a  4c1ccc74e00993733742a3c786dc3c1f
# 19031  7013bcfc1c97fe719a7b5e05e61c12db  2941af76d38100e0f8740a374f1a5dc3
# 20618  f5dd62b788049ad9fc0526e3ad11a097  5e89028e024b381dc84a13a3570decb4
# 22663  5cf925b116421afa85ee25e99b4c34fb  29c35fc91fc13fb5073c8f30505d860d
# 23156  12a95a3c06dbaec84bcfb0e2da5d228a  1e101e0daffaddce8159d25a8e53f2b2
# 26800  c1d4211b3dae76144deccd6c74144a88  684cb238dc5b5d6366244e0e0776b450
# 38290  d69e5d356402adc8cf17e08b5033acfb  68d081753ad4fe22fc4d410a9eb1ca01
# 39334  d77031d6a3c8a52f019764e68f211c69  0bf35cac6cc7327065da879e2d90fae8
# 43834  2ebdfc4f15f23b91474edf87475f108e  29f0540231702fda0cfdee0a310f11aa
# 48401  7002a78c79c519ac54022d4f8a65e6e8  d5de688c321096d15508faae67a27051
# ...

# %%
filtered_processing = null_orders[null_orders['order_status'] == 'processing']
filtered_processing
# Out:
#                                order_id                       customer_id  \
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 324    d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# 741    6a6c7d523fd59eb5bbefc007331af717  d954782ec6c0e911292c8a80757ef28d
# 1192   745e1d4a7f8c4b548881788d4113bb1d  7198d7088442e4ddfe553353d8ddc957
# 1516   1d52ba7197c7acebbb4f826f6585536f  c9c7fe860d602373a9e93f8bfe9d877a
# ...                                 ...                               ...
# 97400  dcdfc540e42725663242bb884c28f0a6  38972104038aa68fcc61277dbf6e7ca9
# 97666  e471815e7114cdb474064f7dbb1a8b67  092c9316ae71b2fe43e526043f351967
# 98089  10951d02d64917a34959abeb8130601e  3e6754e591ff3568ccc5bf69a649918c
# 99140  aea0db338150b526dde24f6fd953a5ed  379a02efdc6a56bd27f99b95fc2f6c06
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
filtered_invoiced = null_orders[null_orders['order_status'] == 'invoiced']
filtered_invoiced
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 455    38b7efdf33dd5561f4f5d4f6e07b0414  021e84751ba0ead75b6d314a6ead88d9
# 1833   51b0dccc8596ce37a930dff2d63a10a2  31bf1057b00f14804278590bbac18b1b
# 2116   5504eaa5a86eb25fa666cf2e6b96c701  a30be38e1ed0ffb39b318bf1d15e98d9
# ...                                 ...                               ...
# 98414  41ad2ae32ee66c07ef3b0301ba02ad27  5c7f8d14a0a12198d1d07167d7d343b3
# 98624  9ffb325177b96c422447e3b9ee9a6270  e4079117ea0dc8bc27274e34c4796515
# 98845  021dac6e3120485db6a77474aa21b979  c40f7f00e91eb8a0da1e58484380a796
# 99031  c526fe83c01c48066394ff5d81f9ab9a  6c678c38f3a0874b7bfeeb2d5fb22876
# 99066  46bdec7cc92d926500bee756ee1df6dc  0cfcefc0ed0af6a2e601540feeac24e7
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
filtered_unavailable = null_orders[null_orders['order_status'] == 'unavailable']
filtered_unavailable
# Out:
#                                order_id                       customer_id  \
# 266    8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 586    c272bcd21c287498b4883c7512019702  9582c5bbecc65eb568e2c1d839b5cba1
# 687    37553832a3a89c9b2db59701c357ca67  7607cd563696c27ede287e515812d528
# 737    d57e15fb07fd180f06ab3926b39edcd2  470b93b3f1cde85550fc74cd3a476c78
# 1160   2f634e2cebf8c0283e7ef0989f77d217  7353b0fb8e8d9675e3a704c60ca44ebe
# ...                                 ...                               ...
# 99147  6cf5c427fb11bc5fe8abefa86aa7ba0b  91ac14a1e50bc022eeecf0c2ba37006a
# 99233  1c7c8ab324927f5b6e52338bd110bef4  95b1767df51d6fa09402267d8de314df
# 99252  aaab15da689073f8f9aa978a390a69d1  df20748206e4b865b2f14a5eabbfcf34
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
filtered_shipped = null_orders[null_orders['order_status'] == 'shipped']
filtered_shipped
# Out:
#                                order_id                       customer_id  \
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# 162    36530871a5e80138db53bcfd8a104d90  4dafe3c841d2d6cc8a8b6d25b35704b9
# 231    4d630f57194f5aba1a3d12ce23e71cd9  6d491c9fe2f04f6e2af6ec033cd8907c
# 299    3b4ad687e7e5190db827e1ae5a8989dd  1a87b8517b7d31373b50396eb15cb445
# ...                                 ...                               ...
# 98534  a59ef0abffbef8ddaae23600b6ee6604  49e64271fb8eeb19851dc7e850e92204
# 98779  dab8a6c6bd6ec448df5b3a6b6cb887bc  394653a10cab83cad40d7e2713f3ab89
# 98932  492aed3c33bac22a8e04138319829283  58466c1166c377a56f6b2ae0d93ffbc0
# 99113  274a7f7e4f1c17b7434a830e9b8759b1  670af30ca5b8c20878fecdafa5ee01b9
# 99181  636cdd02667dc8d76d9296bf20a6890a  c162256b133c76f79181ce61d66545db
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %% [markdown]
# ##### 'order_status' = 'canceled'

# %%
filtered_canceled = null_orders[null_orders['order_status'] == 'canceled']
filtered_canceled
# Out:
#                                order_id                       customer_id  \
# 397    1b9ecfe83cdc259250e1a8aca174f0ad  6d6b50b66d79f80827b6d96751528d30
# 613    714fb133a6730ab81fa1d3c1b2007291  e3fe72696c4713d64d3c10afe71e75ed
# 1058   3a129877493c8189c59c60eb71d97c29  0913cdce793684e52bbfac69d87e91fd
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# ...                                 ...                               ...
# 98791  b159d0ce7cd881052da94fa165617b05  e0c3bc5ce0836b975d6b2a8ce7bb0e3e
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99143  6560fb10610771449cb0463c5ba12199  0d07d0a588caf93cc66b7a8aff86d2fe
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
filtered_canceled_df = df_orders[df_orders['order_status'] == 'canceled']
filtered_canceled_df
# Out:
#                                order_id                       customer_id  \
# 397    1b9ecfe83cdc259250e1a8aca174f0ad  6d6b50b66d79f80827b6d96751528d30
# 613    714fb133a6730ab81fa1d3c1b2007291  e3fe72696c4713d64d3c10afe71e75ed
# 1058   3a129877493c8189c59c60eb71d97c29  0913cdce793684e52bbfac69d87e91fd
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# ...                                 ...                               ...
# 98791  b159d0ce7cd881052da94fa165617b05  e0c3bc5ce0836b975d6b2a8ce7bb0e3e
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99143  6560fb10610771449cb0463c5ba12199  0d07d0a588caf93cc66b7a8aff86d2fe
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
filtered_canceled_df[~filtered_canceled_df.isin(filtered_canceled)].dropna()
# Out:
#                                order_id                       customer_id  \
# 2921   1950d777989f6a877539f53795b4c3c3  1bccb206de9f0f25adc6871a1bcf77b2
# 8791   dabf2b0e35b423f94618bf965fcb7514  5cdec0bb8cbdf53ffc8fdc212cd247c6
# 58266  770d331c84e5b214bd9dc70a10b829d0  6c57e6119369185e575b36712766b0ef
# 59332  8beb59392e21af5eb9547ae1a9938d06  bf609b5741f71697f65ce3852c5d2623
# 92636  65d1e226dfaeb8cdc42f665422522d14  70fc57eeae292675927697fe03ad3ff5
# 94399  2c45c33d2f9cb8ff8b1c86cc28c11c30  de4caa97afa80c8eeac2ff4c8da5b72e
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 2921      canceled      2018-02-19 19:48:52  2018-02-19 20:56:05
# 8791      canceled      2016-10-09 00:56:52  2016-10-09 13:36:58
# 58266     canceled      2016-10-07 14:52:30  2016-10-07 15:07:10
# 59332     canceled      2016-10-08 20:17:50  2016-10-09 14:34:30
# 92636     canceled      2016-10-03 21:01:41  2016-10-04 10:18:57
# ...

# %%
mask = df_order_reviews['order_id'].isin(filtered_canceled_df['order_id'])
mask
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99219    False
# 99220    False
# 99221    False
# 99222    False
# 99223    False
# Name: order_id, Length: 99224, dtype: bool

# %%
diff = df_order_reviews[mask]
diff
# Out:
#                               review_id                          order_id  \
# 19     373cbeecea8286a2b66c97b1b157ec46  583174fbe37d3d5f0d6661be3aad1786
# 89     65dfeb60c40e3cbb0a1838285d86f885  a2714ecbf6eeb3bb9cd7dba6dc1c5e82
# 104    352609f0f2d34ce5d3b8de817ee948d5  96b947c986b42f213c9e6b8ccccedb89
# 170    0c9b6ca9b3beaf0fd5d621f63844ea01  cadd4c5765abf658117f2cc7e2a639c2
# 217    715742f4ae2149e82ead981971912530  73863aca434e1d117e45109bea6f1937
# ...                                 ...                               ...
# 98383  8f8a9e8346753da6be11f381ed26bac3  0ed61f5ab3280ff43b157a6e91942538
# 98441  0159077dd9d4cb22186f4a0c65ac61da  162b2345ef3cc0551c0a32058840a2ec
# 98649  75409037b6d31b5c0a20df9980bf108b  947e9c6bfd83a06953c420ef92d3da6e
# 98716  ec2a789a7b47bf173d5aba7fcb3a10f8  16547d000ee8f177f45827613e2a17f3
# 98866  cb57684d699f3678723ea12f03cd881c  8cacf6d8c088e18ca96ee6d5a138461b
#
#        review_score     review_comment_title  \
# ...

# %%
mask = filtered_canceled_df['order_id'].isin(df_order_reviews['order_id'])
mask
# Out:
# 397      True
# 613      True
# 1058     True
# 1130     True
# 1801     True
#          ...
# 98791    True
# 98909    True
# 99143    True
# 99283    True
# 99347    True
# Name: order_id, Length: 625, dtype: bool

# %%
diff = filtered_canceled_df[~mask]
diff
# Out:
#                                order_id                       customer_id  \
# 5449   c1049eef89915c6beb3604bf3d6588d7  ed16865bcadcea1a00a928bf418a74bf
# 7955   bef875448d5a4f703555d2dd5f8382b5  4a6f6cd7b3fa8d3f9a370adfdad0fa97
# 14792  5abf37ab57e23f69a9c8ab98c4800273  19a045432879d6ddb4fd5611a0e2ba5b
# 21110  7582b8c10039cceafcfe7b13e41a91e2  57bb0f2ff265139687180b2fb387e198
# 29738  cd94dbdc801da0cd93b0c8f33663973d  17ba50f54399b61694fbb138a3831d56
# 32382  d05cf40cb923ba228822414cc52067c3  2f8d1f27dbf2a944f1b5bda2de277ccf
# 36762  f289bb2bb19d49b2e6aa64cb10b0e4bc  2f3dc6fda9c82bef02f23f9387ef137e
# 38902  f7f1e7aa2dda713297141d80375e9509  4da2c9c807e40ef2c7c78cca34ffa0f3
# 50190  a90966534748634cbb133383bf0eee68  509585871d9505d583be980046b14b8a
# 53501  afb61112fb99b07fe17e591c68c0c84c  36b182c39933d55e307096ccc3fd2970
# 61421  9c83e5ae8ff2b5cad999c3dc6129a888  b16ed08790d757ebcbc3533101fb1ace
# 62038  2f6492ebb2badd06db511b63ae7d7f55  0ffc8e8c374a394b0715d65963d641f1
# ...

# %%
diff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 5449 to 97436
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       20 non-null     object
#  1   customer_id                    20 non-null     object
#  2   order_status                   20 non-null     object
#  3   order_purchase_timestamp       20 non-null     object
#  4   order_approved_at              17 non-null     object
#  5   order_delivered_carrier_date   10 non-null     object
#  6   order_delivered_customer_date  0 non-null      object
#  7   order_estimated_delivery_date  20 non-null     object
# dtypes: object(8)
# memory usage: 1.9+ KB

# %% [markdown]
# ### ***products*** *** ~ ( tratar nulos ) ~ ***

# %% [markdown]
# #### df_products

# %%
df_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %% [markdown]
# #### products info and describe

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
df_products.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# #### null

# %%
df_products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
null_products = df_products[df_products.isnull().any(axis=1)]

null_products
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %% [markdown]
# ### ***sellers***

# %% [markdown]
# #### df_sellers

# %%
df_sellers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %% [markdown]
# #### sellers info and describe

# %%
df_sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
df_sellers.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# ### ***product_category_name_translation***

# %% [markdown]
# #### df_product_category_name_translation

# %%
df_product_category_name_translation
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %% [markdown]
# #### product_category_name_translation info and describe

# %%
df_product_category_name_translation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# # **mesclando dataframes por entidades**

# %%
complete_orders = df_orders.merge(df_order_items, on='order_id')

# %%
complete_orders = complete_orders.merge(df_products, on='product_id')

# %%
complete_orders = complete_orders.merge(df_sellers, on='seller_id')

# %%
complete_orders = complete_orders.merge(df_customers, on='customer_id')

# %% [markdown]
# # **análise exploratória de dados**

# %% [markdown]
# ## a) volume de pedidos por mês

# %%
conn = sqlite3.connect(':memory:')

df_orders.to_sql('orders', conn, index=False, if_exists='replace')

query = """

SELECT strftime('%Y-%m', order_purchase_timestamp) AS month,
       COUNT(*) AS order_count
FROM orders
GROUP BY month
ORDER BY month;

"""

orders_per_month = pd.read_sql_query(query, conn)

# %%
orders_per_month['month'] = pd.to_datetime(orders_per_month['month'])

# %%
filtered_month_orders = orders_per_month[orders_per_month['month'] < '2018-09-01'].copy()

# %%
#  média móvel pra suavizar curva e evidenciar tendências

filtered_month_orders['rolling_mean'] = filtered_month_orders['order_count'].rolling(window=3).mean()

# %%
#  gráfico com x = período e y = contagem de pedidos

plt.figure(figsize=(10, 5))
plt.plot(filtered_month_orders['month'], filtered_month_orders['order_count'], label='Original', alpha=0.5)
plt.plot(filtered_month_orders['month'], filtered_month_orders['rolling_mean'], label='Média Móvel (3 meses)', color='red')

plt.title('Volume de Pedidos por Mês')
plt.xlabel('Mês')
plt.ylabel('Número de Pedidos')

plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## a) sazonalidade

# %%
#  convete pra timestamp pra poder usa a matplotlib

orders_per_month['month'] = pd.to_datetime(orders_per_month['month'])

# %%
#  completando valores nulos

orders_per_month = orders_per_month.sort_values('month')
orders_per_month['order_count'] = orders_per_month['order_count'].ffill()

# %%
#  preparando dados da série temporal

orders_per_month = orders_per_month.set_index('month')
orders_per_month = orders_per_month.asfreq('MS')
series = orders_per_month['order_count'].dropna()

# %%
#  decomposição da série temporal e visualização dos componentes

result = seasonal_decompose(series, model='multiplicative', period=12)
result.seasonal.plot(figsize=(10, 4))
plt.title('Componente Sazonal')
plt.show()

# %% [markdown]
# **o gráfico mostra picos claros em novembro, indicando um padrão sazonal relacionado à Black Fiday, sugerindo aumento de consumo recorrente nesse período**

# %% [markdown]
# ## b) distribuição do tempo de entrega dos pedidos

# %%
#  transformando em datetime

df_orders['order_estimated_delivery_date'] = pd.to_datetime(df_orders['order_estimated_delivery_date'])

# %%
#  salva o tempo de entrega

df_orders['order_purchase_timestamp'] = pd.to_datetime(df_orders['order_purchase_timestamp'], errors='coerce')
df_orders['order_estimated_delivery_date'] = pd.to_datetime(df_orders['order_estimated_delivery_date'], errors='coerce')
df_orders['delivery_time'] = (df_orders['order_estimated_delivery_date'] - df_orders['order_purchase_timestamp']).dt.days

# %%
# limpa valores negativos ou nulos

order_delivery = df_orders[df_orders['delivery_time'] > 0].copy()

# %%
#  visualizalção de dados filtando valores relevantes

plt.figure(figsize=(10,6))
sns.histplot(order_delivery['delivery_time'], bins=30, kde=True,color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Distribuição do Tempo de Entrega')
plt.xlabel('Dias para Entrega')
plt.ylabel('Frequência')
plt.axvline(order_delivery['delivery_time'].mean(), color='red', linestyle='--', label=f'Média: {order_delivery["delivery_time"].mean():.2f} dias')
plt.axvline(order_delivery['delivery_time'].median(), color='green', linestyle='--', label=f'Mediana: {order_delivery["delivery_time"].median():.2f} dias')
plt.xlim(0, 60)
plt.legend()
plt.show()

# %% [markdown]
# ## c) relação entre valor do frete e distância de entrerga

# %%
#  usando média de coordenadas pra tratar valores duplicados
#  e ajustando os nomes das colunas

zip_geolocation = df_geolocation.groupby('geolocation_zip_code_prefix')[['geolocation_lat', 'geolocation_lng']].mean()
zip_geolocation = zip_geolocation.reset_index()
zip_geolocation.columns = ['zip_code_prefix', 'lat', 'lng']

# %%
#  adiciona latitude e longitude do 'customer_zip_code_prefix'

complete_orders = complete_orders.merge(zip_geolocation, left_on='customer_zip_code_prefix', right_on='zip_code_prefix', how='left')
complete_orders = complete_orders.rename(columns={'lat': 'customer_lat', 'lng': 'customer_lng'})
complete_orders = complete_orders.drop(columns=['zip_code_prefix'])

# %%
#  adiciona latitude e longitude do 'seller_zip_code_prefix'

complete_orders = complete_orders.merge(zip_geolocation, left_on='seller_zip_code_prefix', right_on='zip_code_prefix', how='left')
complete_orders = complete_orders.rename(columns={'lat': 'seller_lat', 'lng': 'seller_lng'})
complete_orders = complete_orders.drop(columns=['zip_code_prefix'])

# %%
#  salvar só linhas com coordenadas válidas

complete_orders_non_null = complete_orders.dropna(subset=['customer_lat', 'customer_lng', 'seller_lat', 'seller_lng']).copy()

def calculate_distance(row):
  customer_geoloc = (row['customer_lat'], row['customer_lng'])
  seller_geoloc = (row['seller_lat'], row['seller_lng'])
  return haversine(customer_geoloc, seller_geoloc)

#  salva distancia entre customer e seller

complete_orders_non_null['delivery_distance'] = complete_orders_non_null.apply(calculate_distance, axis=1)

# %%
#  limita valores do gráfico

filter_complete_oders = complete_orders_non_null[
    (complete_orders_non_null['delivery_distance'] < 4000) &
    (complete_orders_non_null['freight_value'] < 250)]

# %%
#  visualização de densidade de pedidos

plt.figure(figsize=(10, 6))
plt.hexbin(filter_complete_oders['delivery_distance'], filter_complete_oders['freight_value'], gridsize=50, cmap='Blues', bins='log')
plt.colorbar(label='log(N)')
plt.xlabel("delivery_distance")
plt.ylabel("freight_value")
plt.show()

# %% [markdown]
# ## d) categorias mais vendidas e faturamento

# %% [markdown]
# ## e) estados com maior valor médio de pedido

# %% [markdown]
# # **solução de problemas de negócio**

# %% [markdown]
# ## 1. análise de retenção

# %% [markdown]
# ## 2. predição de atraso

# %% [markdown]
# ## 3. segmentação de clientes

# %% [markdown]
# ## 4. análise de satisfação

# %% [markdown]
# # **visualização e dashboads**

# %% [markdown]
# ## 1. evolução de vendas ao longo do tempo

# %% [markdown]
# ## 2.  mapa de calor: concentração de vendas por região/estado do Brasil

# %% [markdown]
# ## 3. relação entre avaliação do cliente e tempo de entrega

# %% [markdown]
# ## 4. dashboard de análise dos vendedores
